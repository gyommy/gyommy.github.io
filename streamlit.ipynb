# %% [markdown]
# <a href="https://colab.research.google.com/github/gyommy/gyommy.github.io/blob/main/streamlit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
link = 'https://raw.githubusercontent.com/murpi/wilddata/master/quests/cars.csv'
data = pd.read_csv(link)

# %%
data
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year continent
# 0    14.0          8          350  165       4209          12  1972       US.
# 1    31.9          4           89   71       1925          14  1980   Europe.
# 2    17.0          8          302  140       3449          11  1971       US.
# 3    15.0          8          400  150       3761          10  1971       US.
# 4    30.5          4           98   63       2051          17  1978       US.
# ..    ...        ...          ...  ...        ...         ...   ...       ...
# 256  17.0          8          305  130       3840          15  1980       US.
# 257  36.1          4           91   60       1800          16  1979    Japan.
# 258  22.0          6          232  112       2835          15  1983       US.
# 259  18.0          6          232  100       3288          16  1972       US.
# 260  22.0          6          250  105       3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
data_corr = data[['mpg', 'weightlbs', 'hp', 'continent', 'cubicinches']]

# %%
sns.pairplot(data_corr, hue="continent")

# %%
sns.set(rc = {'figure.figsize' : (10, 5)})
sns.boxplot(data = data,
            x = 'hp',
            y = 'continent')

# %%
sns.displot(data, x="hp", hue="continent", kind="kde", multiple="stack")

# %%
sns.jointplot(
    data=data,
    x="hp", y="weightlbs", hue="continent"
)
